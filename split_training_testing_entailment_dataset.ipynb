# %%
import pandas as pd
import numpy as np
import sys
from sklearn.model_selection import StratifiedShuffleSplit

# %%
def get_train_test_split(filename):
    data = pd.read_csv(filename)
    X = np.array(data.iloc[:,1:3])
    y = np.array(data.iloc[:,3])
    
    sss = StratifiedShuffleSplit(n_splits=2, test_size=0.90, random_state=0)
 
    for train_index, test_index in sss.split(X, y):
        print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
    return X_train, y_train, X_test, y_test

def create_training_testing_files(X_train, y_train, X_test, y_test):
    df_train = pd.DataFrame(X_train)
    df_test = pd.DataFrame(X_test)
    df_train['label'] = y_train
    df_test['label'] = y_test
    df_train.to_csv('data/entailment_train_3.csv')
    df_test.to_csv('data/entailment_test_3.csv')

# %%
filename = 'data/entailment_test.csv'

# %%
X_train, y_train, X_test, y_test = get_train_test_split(filename)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# TRAIN: [ 941 3224 1882 4728  473  399 1335  171 4801 2584 1197 2987 3303 4025
#   974 3004  519 1298 2281 1339 4902 2613 5038 4762 2206 4714  323 2267
#  1124 2433 1194 4928 2871 4561 4831  724 1550  118 4884 2301 1680 2367
#  4598 3017 3007 4925 1742 2880 4135 1796  278 3180 3179 3178 4350 2382
#  1005 1026 3980 2592 1163  134 1080 3204 3889  649 1441 3526 3823  415
#  4887  355 4274 2723 1020  537  297 4514 1855 3711 3972 2372 3746 3761
#  3032   54 2796  471  770  514 4031 1380 4108 3713 1149   73 3856  457
#  2732 4845  966  717 1833 3793  394 3670  625 2027 1400  419 2390 2366
#  1711 2921 3990 5007 3262 2933 4919 1332 1576 4572 3446 2248 4333 2894
#  1217 3222  279  883 4395 3625 1768 1278 1773 4931 3202 1622  762  136
#  3069 1075 4096 3191 3733 2065 4441 1014 4356 1760 1905 2825  176 1702
#  4365 2700 2160  857 1560   80 4662 2287 4965 4409  923 1015 3782 4501
#  2102 3107 5021 3320 2708 4885 2087  603 1826 2555 2520 3417 5045 2909
# ...

# %%
create_training_testing_files(X_train, y_train, X_test, y_test)
